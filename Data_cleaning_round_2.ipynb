# %% [markdown]
# <a href="https://colab.research.google.com/github/adilkamal2478/Adil_Pandas_Data_Preprocessing/blob/main/Data_cleaning_round_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Data_processing/smartphone_cleaned_v2.csv")

# %%
df.head()
# Out:
#   brand_name                             model   price  rating  has_5g  \
# 0      apple               Apple iPhone 18 Pro  164900    85.0    True
# 1       vivo  Vivo T4 Pro 5G (8GB RAM + 256GB)   29999    72.0    True
# 2      apple                  Apple iPhone Duo  299900    84.0    True
# 3      apple           Apple iPhone 18 Pro Max  179900    86.0    True
# 4     realme     Realme P1 5G (8GB RAM+ 128GB)   14999    58.0    True
#
#    has_nfc  has_ir_blaster     processor_name processor_brand  num_cores  \
# 0     True           False      Apple A20 Pro           apple  Hexa Core
# 1    False            True  Snapdragon 7 Gen4      snapdragon  Octa Core
# 2     True           False      Apple A20 Pro           apple  Hexa Core
# 3     True           False      Apple A20 Pro           apple  Hexa Core
# 4    False           False     Dimensity 7050       dimensity  Octa Core
#
#    processor_speed  ram_capacity  internal_memory  battery_capacity  \
# ...

# %%
df.shape
# Out:
# (921, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 921 entries, 0 to 920
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand_name            921 non-null    object
#  1   model                 921 non-null    object
#  2   price                 921 non-null    int64
#  3   rating                786 non-null    float64
#  4   has_5g                921 non-null    bool
#  5   has_nfc               921 non-null    bool
#  6   has_ir_blaster        921 non-null    bool
#  7   processor_name        911 non-null    object
#  8   processor_brand       911 non-null    object
#  9   num_cores             909 non-null    object
#  10  processor_speed       843 non-null    float64
#  11  ram_capacity          921 non-null    int64
#  12  internal_memory       921 non-null    int64
#  13  battery_capacity      921 non-null    float64
#  14  fast_charging         921 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# brand_name                0
# model                     0
# price                     0
# rating                  135
# has_5g                    0
# has_nfc                   0
# has_ir_blaster            0
# processor_name           10
# processor_brand          10
# num_cores                12
# processor_speed          78
# ram_capacity              0
# internal_memory           0
# battery_capacity          0
# fast_charging             0
# screen_size               0
# refresh_rate              0
# resolution                0
# primary_camera_front      0
# primary_camera_rear       0
# num_rear_cameras          0
# num_front_cameras         0
# extended_memory           1
# os                        0
# dtype: int64

# %%
df['brand_name'].value_counts()
# Out:
# brand_name
# samsung     160
# realme      142
# oppo         87
# vivo         71
# xiaomi       70
# motorola     64
# poco         53
# oneplus      42
# apple        39
# iqoo         25
# google       22
# tecno        21
# lava         21
# infinix      20
# nothing      16
# ai+          15
# peace        11
# itel          9
# ringme        8
# boltt         5
# alcatel       5
# hmd           3
# coolpad       2
# philips       2
# mtr           2
# wobble        2
# honor         2
# acer          1
# asus          1
# Name: count, dtype: int64

# %%
# top 10 phone brands

df['brand_name'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='brand_name'>

# %%
# price col
df['price'].describe()
# Out:
# count       921.000000
# mean      43111.231270
# std       45770.416687
# min        5800.000000
# 25%       18490.000000
# 50%       28999.000000
# 75%       46999.000000
# max      449900.000000
# Name: price, dtype: float64

# %%
df['price'].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.histplot(df['price'],kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df['price'].skew()
# Out:
# np.float64(3.5158980381828417)

# %%
sns.boxplot(df[df['price']<200000]['price'])
# Out:
# <Axes: ylabel='price'>

# %%
df[df['price']>200000]
# Out:
#     brand_name                                             model   price  \
# 2        apple                                  Apple iPhone Duo  299900
# 24       apple                            Apple iPhone Duo (2TB)  449900
# 41       apple                            Apple iPhone Duo (1TB)  374900
# 63       apple                     Apple iPhone 18 Pro Max (1TB)  254900
# 72       apple                     Apple iPhone 18 Pro Max (2TB)  329900
# 75       apple                   Apple iPhone 18 Pro Max (512GB)  204900
# 106      apple                         Apple iPhone 18 Pro (1TB)  239900
# 144      apple                          Apple iPhone Duo (512GB)  324900
# 185      apple                         Apple iPhone 18 Pro (2TB)  314900
# 271    samsung    Samsung Galaxy Z Fold 8 Ultra (16GB RAM + 1TB)  254999
# 398    samsung          Samsung Galaxy Z Fold 8 (16GB RAM + 1TB)  234999
# 649    samsung          Samsung Galaxy Z Fold 8 (16GB RAM + 1TB)  234999
# ...

# %%
df['price'].isnull().sum()
# Out:
# np.int64(0)

# %%
# rating column

df['rating'].describe()
# Out:
# count    786.000000
# mean      68.473282
# std       11.680237
# min       50.000000
# 25%       59.000000
# 50%       66.000000
# 75%       76.000000
# max       98.000000
# Name: rating, dtype: float64

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(135)

# %%
sns.histplot(df['rating'],kde=True)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
df['rating'].skew()
# Out:
# np.float64(0.5303042205149617)

# %%
sns.boxplot(df['rating'])
# Out:
# <Axes: ylabel='rating'>

# %%
# has_5g

sns.countplot(x='has_5g', data=df)
# Out:
# <Axes: xlabel='has_5g', ylabel='count'>

# %%
df['has_5g'].value_counts()
# Out:
# has_5g
# True     786
# False    135
# Name: count, dtype: int64

# %%
# has_nfc

sns.countplot(x = 'has_nfc' , data=df)
# Out:
# <Axes: xlabel='has_nfc', ylabel='count'>

# %%
df['has_nfc'].value_counts()
# Out:
# has_nfc
# False    513
# True     408
# Name: count, dtype: int64

# %%
df['has_nfc'].isnull().sum()
# Out:
# np.int64(0)

# %%
# has_ir_blaster
sns.countplot(x= 'has_ir_blaster' , data = df)
# Out:
# <Axes: xlabel='has_ir_blaster', ylabel='count'>

# %%
df['has_ir_blaster'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['has_ir_blaster'].value_counts()
# Out:
# has_ir_blaster
# False    621
# True     300
# Name: count, dtype: int64

# %%
# processor_brand

df['processor_brand'].value_counts()
# Out:
# processor_brand
# dimensity     360
# snapdragon    305
# unisoc         73
# exynos         63
# helio          38
# apple          26
# tensor         22
# bionic         13
# tiger           5
# mtk6739         3
# qualcomm        2
# 512             1
# Name: count, dtype: int64

# %%
temp_df = df[df['processor_brand'] == 'qualcomm']

# %%
df.loc[temp_df.index, 'processor_brand'] = 'snapdragon'

# %%
df['processor_brand'] = df['processor_brand'].str.replace('apple','bionic')
df['processor_brand'] = df['processor_brand'].str.replace('samsung','exynos')
df['processor_brand'] = df['processor_brand'].str.replace('mtk6739','mediatek')

# %%
df['processor_name'] = df['processor_name'].replace('512 MHz Processor' , 'MediaTek Cortex-A7 quad-core')
df['processor_brand'] = df['processor_brand'].replace('512' , 'mediatek')

# %%
df[df['processor_brand'].isnull()]
# Out:
#     brand_name                                model  price  rating  has_5g  \
# 511     ringme  Ringme Bold 17 Pro (6GB RAM + 64GB)  13000     NaN   False
# 597      peace                        Peace i17 Air   9999     NaN   False
# 647     ringme                   Ringme Bold 17 Pro   9753     NaN   False
# 684      peace                        Peace i Ultra  10999     NaN   False
# 686     ringme                 Ringme Bold 26 Ultra   9999     NaN   False
# 687       itel                   itel Zeno 100 Lite   8599     NaN   False
# 757      peace                  Peace Honor 40 Mini   7999     NaN   False
# 759     ringme                   Ringme Bold 16 Pro   9899     NaN   False
# 805    samsung                   Samsung Galaxy A13  15650     NaN   False
# 825     ringme                      Ringme Bold S16   9999     NaN   False
#
#      has_nfc  has_ir_blaster processor_name processor_brand    num_cores  \
# ...

# %%
# Replace NaN in 'processor_name' column using row index

df.loc[511, 'processor_name'] = "MediaTek MT6739"   # Ringme Bold 17 Pro (6GB RAM + 64GB)
df.loc[597, 'processor_name'] = "MediaTek Helio MT8125"                  # Peace i17 Air
df.loc[647, 'processor_name'] = "MediaTek MT6739"   # Ringme Bold 17 Pro (9753 variant)
df.loc[684, 'processor_name'] = "Spreadtrum/Unisoc"  # Peace i Ultra
df.loc[686, 'processor_name'] = "MediaTek MT6739"   # Ringme Bold 26 Ultra
df.loc[687, 'processor_name'] = "Unisoc T7100"  # itel Zeno 100 Lite
df.loc[757, 'processor_name'] = "Qualcomm Snapdragon 6s Gen 3"  # Peace Honor 40 Mini
df.loc[759, 'processor_name'] = "MediaTek MT6762 ,Helio P22" # Ringme Bold 16 Pro
df.loc[805, 'processor_name'] = "Samsung Exynos 850"   # Samsung Galaxy A13
df.loc[825, 'processor_name'] = "MediaTek MT6762 ,Helio P22" # Ringme Bold S16

# %%
# filling nan values in processor brand

df.loc[511, 'processor_brand'] = "mediatek"   # Ringme Bold 17 Pro (6GB RAM + 64GB)
df.loc[597, 'processor_brand'] = "mediatek"                  # Peace i17 Air
df.loc[647, 'processor_brand'] = "mediatek"   # Ringme Bold 17 Pro (9753 variant)
df.loc[684, 'processor_brand'] = "unisoc"  # Peace i Ultra
df.loc[686, 'processor_brand'] = "mediatek"   # Ringme Bold 26 Ultra
df.loc[687, 'processor_brand'] = "unisoc"  # itel Zeno 100 Lite
df.loc[757, 'processor_brand'] = "snapdragon"  # Peace Honor 40 Mini
df.loc[759, 'processor_brand'] = "mediatek" # Ringme Bold 16 Pro
df.loc[805, 'processor_brand'] = "exynos"   # Samsung Galaxy A13
df.loc[825, 'processor_brand'] = "mediatek" # Ringme Bold S16

# %%
df1 = df.copy()

# %%
# Show all columns when printing a DataFrame
pd.set_option('display.max_columns', None)

# %%
df1.head()
# Out:
#   brand_name                             model   price  rating  has_5g  \
# 0      apple               Apple iPhone 18 Pro  164900    85.0    True
# 1       vivo  Vivo T4 Pro 5G (8GB RAM + 256GB)   29999    72.0    True
# 2      apple                  Apple iPhone Duo  299900    84.0    True
# 3      apple           Apple iPhone 18 Pro Max  179900    86.0    True
# 4     realme     Realme P1 5G (8GB RAM+ 128GB)   14999    58.0    True
#
#    has_nfc  has_ir_blaster     processor_name processor_brand  num_cores  \
# 0     True           False      Apple A20 Pro          bionic  Hexa Core
# 1    False            True  Snapdragon 7 Gen4      snapdragon  Octa Core
# 2     True           False      Apple A20 Pro          bionic  Hexa Core
# 3     True           False      Apple A20 Pro          bionic  Hexa Core
# 4    False           False     Dimensity 7050       dimensity  Octa Core
#
#    processor_speed  ram_capacity  internal_memory  battery_capacity  \
# ...

# %%
df1['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core      830
# Hexa Core       39
# Deca Core       19
# Single Core     10
# Dual Core        6
# Nine Core        3
# Quad Core        2
# Name: count, dtype: int64

# %%
df1[df1['num_cores'].isnull()]
# Out:
#     brand_name                                      model   price  rating  \
# 74      google                            Google Pixel 11   82300    74.0
# 164     google                        Google Pixel 11 Pro  119999    85.0
# 302     google                   Google Pixel 11 Pro Fold  186999    88.0
# 349     google                     Google Pixel 11 Pro XL  134999    83.0
# 505     google     Google Pixel 11 Pro (16GB RAM + 512GB)  134999    86.0
# 528        mtr                                MTR M17 Max    9600     NaN
# 591     google     Google Pixel 11 Pro (16GB RAM + 512GB)  134999    86.0
# 593     google  Google Pixel 11 Pro XL (16GB RAM + 512GB)  149999    84.0
# 596       lava                           Lava Virat V1 4G    9949     NaN
# 597      peace                              Peace i17 Air    9999     NaN
# 645     google      Google Pixel 11 5G (12GB RAM + 512GB)  104999    75.0
# 825     ringme                            Ringme Bold S16    9999     NaN
#
# ...

# %%
# Fill num_cores column by index

df1.loc[74, 'num_cores']   = "Octa Core"   # Google Pixel 11
df1.loc[164, 'num_cores']  = "Octa Core"   # Google Pixel 11 Pro
df1.loc[302, 'num_cores']  = "Octa Core"   # Google Pixel 11 Pro Fold
df1.loc[349, 'num_cores']  = "Octa Core"   # Google Pixel 11 Pro XL
df1.loc[505, 'num_cores']  = "Octa Core"   # Google Pixel 11 Pro (16GB RAM + 512GB)
df1.loc[528, 'num_cores']  = "Quad Core"   # MTR M17 Max
df1.loc[591, 'num_cores']  = "Octa Core"   # Google Pixel 11 Pro (16GB RAM + 512GB)
df1.loc[593, 'num_cores']  = "Octa Core"   # Google Pixel 11 Pro XL (16GB RAM + 512GB)
df1.loc[596, 'num_cores']  = "Octa Core"   # Lava Virat V1 4G (Unisoc 9863a)
df1.loc[597, 'num_cores']  = "Octa Core"   # Peace i17 Air (Helio MT8125)
df1.loc[645, 'num_cores']  = "Octa Core"   # Google Pixel 11 5G (12GB RAM + 512GB)
df1.loc[825, 'num_cores']  = "Quad Core"   # Ringme Bold S16 (Helio P22 variant)

# %%
df1['processor_speed'].describe()
# Out:
# count    843.000000
# mean       2.690142
# std        0.638001
# min        1.300000
# 25%        2.400000
# 50%        2.500000
# 75%        3.000000
# max        4.740000
# Name: processor_speed, dtype: float64

# %%
df1['processor_speed'].value_counts()
# Out:
# processor_speed
# 2.40    214
# 2.50     85
# 2.20     60
# 2.60     57
# 2.00     41
# 2.30     36
# 1.80     33
# 2.80     28
# 3.20     27
# 3.00     24
# 3.80     22
# 2.70     21
# 3.35     19
# 3.30     15
# 3.25     14
# 3.40     13
# 2.84     13
# 4.74     11
# 4.47     10
# 2.90     10
# 4.60     10
# 3.10      7
# 4.04      6
# 4.32      6
# 3.78      5
# 1.30      5
# 3.73      4
# 3.63      4
# 3.36      4
# 2.85      4
# 1.60      4
# 1.70      4
# 2.63      4
# 4.21      3
# 3.46      3
# 2.96      3
# 3.84      2
# 2.36      2
# 1.82      2
# 3.11      2
# 3.39      2
# 4.05      1
# 3.22      1
# 2.73      1
# 2.39      1
# Name: count, dtype: int64

# %%
sns.displot(kind='kde',data=df1,x='processor_speed')

# %%
df1['processor_speed'].skew()
# Out:
# np.float64(1.2414020521479332)

# %%
sns.boxplot(df1['processor_speed'])
# Out:
# <Axes: ylabel='processor_speed'>

# %%
df1['processor_speed'].isnull().sum()
# Out:
# np.int64(78)

# %%
pd.set_option('display.max_rows', None)
# pd.reset_option('display.max_rows')

# %%
df1[df1['processor_speed'].isnull()]['model']
# Out:
# 0                            Apple iPhone 18 Pro
# 2                               Apple iPhone Duo
# 3                        Apple iPhone 18 Pro Max
# 6                                Apple iPhone 17
# 24                        Apple iPhone Duo (2TB)
# 28                              Realme P4 Pro 5G
# 31                       Apple iPhone 17 Pro Max
# 41                        Apple iPhone Duo (1TB)
# 48                   Apple iPhone 18 Pro (512GB)
# 50                           Apple iPhone 17 Pro
# 63                 Apple iPhone 18 Pro Max (1TB)
# 72                 Apple iPhone 18 Pro Max (2TB)
# 74                               Google Pixel 11
# 75               Apple iPhone 18 Pro Max (512GB)
# 106                    Apple iPhone 18 Pro (1TB)
# 111                                   OnePlus N6
# 144                     Apple iPhone Duo (512GB)
# 164                          Google Pixel 11 Pro
# 185                    Apple iPhone 18 Pro (2TB)
# ...

# %%
# replacing nan values of c

df1.loc[6, 'processor_speed'] = 4.26       # Apple iPhone 17
df1.loc[31, 'processor_speed'] = 4.26      # Apple iPhone 17 Pro Max
df1.loc[50, 'processor_speed'] = 4.26      # Apple iPhone 17 Pro
df1.loc[74, 'processor_speed'] = 4.11      # Google Pixel 11
df1.loc[164, 'processor_speed'] = 4.11     # Google Pixel 11 Pro
df1.loc[203, 'processor_speed'] = 4.26     # Apple iPhone 17 (512GB)
df1.loc[212, 'processor_speed'] = 4.26     # Apple iPhone 17e
df1.loc[246, 'processor_speed'] = 2.40     # OnePlus N6x
df1.loc[248, 'processor_speed'] = 4.26     # Apple iPhone Air
df1.loc[285, 'processor_speed'] = 2.40     # Poco M8
df1.loc[296, 'processor_speed'] = 4.26     # Apple iPhone 17 Pro Max (512GB)
df1.loc[302, 'processor_speed'] = 4.11     # Google Pixel 11 Pro Fold
df1.loc[311, 'processor_speed'] = 2.40     # Oppo F33
df1.loc[335, 'processor_speed'] = 2.80     # Google Pixel 6A
df1.loc[349, 'processor_speed'] = 4.11     # Google Pixel 11 Pro XL
df1.loc[377, 'processor_speed'] = 4.26     # Apple iPhone 17 Pro (512GB)
df1.loc[397, 'processor_speed'] = 2.70     # Lava Virat V1 5G
df1.loc[405, 'processor_speed'] = 4.26     # Apple iPhone 17 Pro Max (1TB)
df1.loc[464, 'processor_speed'] = 2.50     # Realme 15 5G
df1.loc[481, 'processor_speed'] = 2.40     # OnePlus N6x (4GB RAM + 128GB)
df1.loc[505, 'processor_speed'] = 4.11     # Google Pixel 11 Pro (16GB RAM + 512GB)
df1.loc[563, 'processor_speed'] = 2.40     # Oppo F33 5G (8GB RAM + 128GB)
df1.loc[591, 'processor_speed'] = 4.11     # Google Pixel 11 Pro (16GB RAM + 512GB)
df1.loc[593, 'processor_speed'] = 4.11     # Google Pixel 11 Pro XL (16GB RAM + 512GB)
df1.loc[620, 'processor_speed'] = 4.26     # Apple iPhone 17 Pro (1TB)
df1.loc[645, 'processor_speed'] = 4.11     # Google Pixel 11 5G (12GB RAM + 512GB)
df1.loc[656, 'processor_speed'] = 2.40     # Oppo F33 5G (8GB RAM + 256GB)
df1.loc[687, 'processor_speed'] = 1.82     # itel Zeno 100 Lite
df1.loc[688, 'processor_speed'] = 1.80     # Itel Zeno 100 Pro
df1.loc[690, 'processor_speed'] = 2.70     # Lava Bold N2 5G (4GB RAM + 128GB)
df1.loc[694, 'processor_speed'] = 2.70     # Lava Bold N2 5G
df1.loc[706, 'processor_speed'] = 2.40     # Poco M8 5G (8GB RAM + 256GB)
df1.loc[731, 'processor_speed'] = 1.80     # itel A70 4G (4GB RAM + 256GB)
df1.loc[769, 'processor_speed'] = 4.26     # Apple iPhone 17e (512GB)
df1.loc[772, 'processor_speed'] = 4.26     # Apple iPhone Air (1TB)
df1.loc[774, 'processor_speed'] = 2.50     # Realme 15 5G (8GB RAM + 256GB)
df1.loc[830, 'processor_speed'] = 2.40     # Poco M8 5G (8GB RAM + 128GB)
df1.loc[831, 'processor_speed'] = 1.60     # itel Zeno 20 Max
df1.loc[837, 'processor_speed'] = 4.26     # Apple iPhone Air (512GB)
df1.loc[838, 'processor_speed'] = 2.50     # Realme 15 5G (12GB RAM + 256GB)
df1.loc[853, 'processor_speed'] = 1.80     # itel A70 4G
df1.loc[862, 'processor_speed'] = 2.40     # Samsung Galaxy F14 5G (6GB RAM + 128GB)
df1.loc[920, 'processor_speed'] = 1.60     # Lava Yuva Star 3

# %%
df1['battery_capacity'].describe()
# Out:
# count      921.000000
# mean      5689.523181
# std       1220.044912
# min          6.850000
# 25%       5000.000000
# 50%       5400.000000
# 75%       6500.000000
# max      10001.000000
# Name: battery_capacity, dtype: float64

# %%
sns.displot(kind='kde',data=df1,x='battery_capacity')

# %%
df1[df1['battery_capacity'] < 4000]
# Out:
#     brand_name                                       model   price  rating  \
# 6        apple                             Apple iPhone 17   82900    76.0
# 16       apple                             Apple iPhone 16   69900    70.0
# 45       apple                             Apple iPhone 15   59900    66.0
# 50       apple                         Apple iPhone 17 Pro  130490    74.0
# 83       apple                             Apple iPhone 13   45690    55.0
# 139    samsung                     Samsung Galaxy S25 Edge   60800    80.0
# 187      apple                     Apple iPhone 15 (256GB)   69900    66.0
# 192      apple                     Apple iPhone 16 (256GB)   79900    70.0
# 203      apple                     Apple iPhone 17 (512GB)  102900    77.0
# 248      apple                            Apple iPhone Air  101900    64.0
# 263    samsung                     Samsung Galaxy Z Flip 3   41499    67.0
# ...

# %%
df1['battery_capacity'] = df1['battery_capacity'].replace(20.00 , 5000)
df1['battery_capacity'] = df1['battery_capacity'].replace(6.85 , 5115)

# %%
df1['fast_charging'].describe()
# Out:
# count    921.000000
# mean      44.078176
# std       31.326374
# min       -1.000000
# 25%       18.000000
# 50%       44.000000
# 75%       68.000000
# max      150.000000
# Name: fast_charging, dtype: float64

# %%
df1[df1['fast_charging']== -1]
# Out:
#     brand_name                                   model  price  rating  has_5g  \
# 331     ringme                Ringme Bold S170 Air Pro  13000     NaN   False
# 472   motorola                 Motorola Moto G06 Power  13079     NaN   False
# 511     ringme     Ringme Bold 17 Pro (6GB RAM + 64GB)  13000     NaN   False
# 523     realme                               Realme C2   6999     NaN   False
# 528        mtr                             MTR M17 Max   9600     NaN   False
# 597      peace                           Peace i17 Air   9999     NaN   False
# 647     ringme                      Ringme Bold 17 Pro   9753     NaN   False
# 660      peace         Peace Honor 20 (4GB RAM + 64GB)   7999     NaN   False
# 663        mtr                             MTR M16 Pro   6400     NaN   False
# 664      peace                            Peace Mini 6   5999     NaN   False
# 684      peace                           Peace i Ultra  10999     NaN   False
# ...

# %%
def fast(row):

  if row['fast_charging'] == -1:
    return 0
  else:
    return 1

# %%
x = df1.apply(fast,axis=1)
df1.insert(12,'fast_charging_available',x)

# %%
df1.head()
# Out:
#   brand_name                             model   price  rating  has_5g  \
# 0      apple               Apple iPhone 18 Pro  164900    85.0    True
# 1       vivo  Vivo T4 Pro 5G (8GB RAM + 256GB)   29999    72.0    True
# 2      apple                  Apple iPhone Duo  299900    84.0    True
# 3      apple           Apple iPhone 18 Pro Max  179900    86.0    True
# 4     realme     Realme P1 5G (8GB RAM+ 128GB)   14999    58.0    True
#
#    has_nfc  has_ir_blaster     processor_name processor_brand  num_cores  \
# 0     True           False      Apple A20 Pro          bionic  Hexa Core
# 1    False            True  Snapdragon 7 Gen4      snapdragon  Octa Core
# 2     True           False      Apple A20 Pro          bionic  Hexa Core
# 3     True           False      Apple A20 Pro          bionic  Hexa Core
# 4    False           False     Dimensity 7050       dimensity  Octa Core
#
#    processor_speed  ram_capacity  fast_charging_available  internal_memory  \
# ...

# %%
df['fast_charging'] = df['fast_charging'].apply(lambda x:np.nan if x == 0 or x == -1 else x)

# %%
df1['fast_charging'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1['fast_charging'].value_counts()
# Out:
# fast_charging
#  45     151
#  80     112
#  25      99
#  0       72
#  33      59
#  15      59
#  18      52
#  90      48
#  44      36
# -1       32
#  100     29
#  67      27
#  10      25
#  30      24
#  120     23
#  60      18
#  68      15
#  65      11
#  50       9
#  20       7
#  66       5
#  27       2
#  125      2
#  23       1
#  70       1
#  150      1
#  5        1
# Name: count, dtype: int64

# %%
df1['fast_charging'] = df1['fast_charging'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 921 entries, 0 to 920
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   brand_name               921 non-null    object
#  1   model                    921 non-null    object
#  2   price                    921 non-null    int64
#  3   rating                   786 non-null    float64
#  4   has_5g                   921 non-null    bool
#  5   has_nfc                  921 non-null    bool
#  6   has_ir_blaster           921 non-null    bool
#  7   processor_name           921 non-null    object
#  8   processor_brand          921 non-null    object
#  9   num_cores                921 non-null    object
#  10  processor_speed          886 non-null    float64
#  11  ram_capacity             921 non-null    int64
#  12  fast_charging_available  921 non-null    int64
#  13  internal_memory          921 non-null    int64
# ...

# %%
df1['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8     352
# 12    188
# 4     171
# 6     149
# 16     36
# 3      22
# 2       2
# 18      1
# Name: count, dtype: int64

# %%
df1['ram_capacity'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1[df1['internal_memory'].isnull()]
# Out:
# Empty DataFrame
# Columns: [brand_name, model, price, rating, has_5g, has_nfc, has_ir_blaster, processor_name, processor_brand, num_cores, processor_speed, ram_capacity, fast_charging_available, internal_memory, battery_capacity, fast_charging, screen_size, refresh_rate, resolution, primary_camera_front, primary_camera_rear, num_rear_cameras, num_front_cameras, extended_memory, os]
# Index: []

# %%
df1['internal_memory'].value_counts()
# Out:
# internal_memory
# 128     397
# 256     310
# 64      107
# 512      77
# 32       13
# 1024     13
# 2048      3
# 16        1
# Name: count, dtype: int64

# %%
df1['screen_size'].describe()
# Out:
# count    921.000000
# mean       6.694452
# std        0.342652
# min        3.750000
# 25%        6.600000
# 50%        6.720000
# 75%        6.790000
# max        8.090000
# Name: screen_size, dtype: float64

# %%
sns.displot(kind='kde',data=df1,x='screen_size')

# %%
df1['screen_size'].skew()
# Out:
# np.float64(-2.0792542804030436)

# %%
sns.boxplot(df1['screen_size'])
# Out:
# <Axes: ylabel='screen_size'>

# %%
df1['extended_memory'].value_counts()
# Out:
# extended_memory
# 0                480
#  1 TB            179
#  2 TB            111
# Not Specified    106
#  256 GB           17
#  512 GB           12
#  128 GB            8
#  1.5 TB            7
# Name: count, dtype: int64

# %%
df1['extended_memory_available'] = df1['extended_memory'].apply(lambda x:0 if x == '0' else 1)

# %%
def extended_extractor(row):

  if row['extended_memory_available'] == 0:
    return np.nan
  else:
    if row['extended_memory'] == '1 TB':
      return 1024
    elif row['extended_memory'] == '2 TB':
      return 2048
    elif row['extended_memory'] == '1.5 TB':
      return 1536
    elif row['extended_memory'] == '512 GB':
      return 512
    elif row['extended_memory'] == '256 GB':
      return 256
    elif row['extended_memory'] == 'Not Specified':
      return np.nan
    elif row['extended_memory'] == '128 GB':
      return 128

# %%
df1['extended_memory'] = (
    df1['extended_memory']
    .str.replace(r'\s+', ' ', regex=True)
    .str.strip()
)

# %%
df1.loc[920]['extended_memory'] == '256 GB'
# Out:
# True

# %%
print(extended_extractor(df1.loc[920]))
# Out:
# None

# %%
df1['extended_memory_available'].value_counts()
# Out:
# extended_memory_available
# 0    480
# 1    441
# Name: count, dtype: int64

# %%
df1[df1['extended_memory'].isnull()]
# Out:
#     brand_name            model  price  rating  has_5g  has_nfc  \
# 825     ringme  Ringme Bold S16   9999     NaN   False    False
#
#      has_ir_blaster              processor_name processor_brand  num_cores  \
# 825           False  MediaTek MT6762 ,Helio P22        mediatek  Quad Core
#
#      processor_speed  ram_capacity  fast_charging_available  internal_memory  \
# 825              NaN             3                        0               64
#
#      battery_capacity  fast_charging  screen_size  refresh_rate resolution  \
# 825            5115.0             -1         6.85            60  128 x 160
#
#      primary_camera_front  primary_camera_rear  num_rear_cameras  \
# 825                   0.0                 13.0                 1
#
#      num_front_cameras extended_memory             os  \
# 825                  0             NaN  Not Specified
#
#      extended_memory_available
# 825                          1

# %%
df1['extended_memory'] = df1['extended_memory'].replace(0 , '0')

# %%
df1['extended_memory'].value_counts()
# Out:
# extended_memory
# 0                480
# 1 TB             179
# 2 TB             111
# Not Specified    106
# 256 GB            17
# 512 GB            12
# 128 GB             8
# 1.5 TB             7
# Name: count, dtype: int64

# %%
df1['extended_upto'] = np.nan

df1.loc[df1['extended_memory'] == '1 TB', 'extended_upto'] = 1024
df1.loc[df1['extended_memory'] == '2 TB', 'extended_upto'] = 2048
df1.loc[df1['extended_memory'] == '1.5 TB', 'extended_upto'] = 1536
df1.loc[df1['extended_memory'] == '512 GB', 'extended_upto'] = 512
df1.loc[df1['extended_memory'] == '256 GB', 'extended_upto'] = 256
df1.loc[df1['extended_memory'] == '128 GB', 'extended_upto'] = 128

# %%
df1['extended_upto'].isnull().sum()
# Out:
# np.int64(587)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 921 entries, 0 to 920
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 921 non-null    object
#  1   model                      921 non-null    object
#  2   price                      921 non-null    int64
#  3   rating                     786 non-null    float64
#  4   has_5g                     921 non-null    bool
#  5   has_nfc                    921 non-null    bool
#  6   has_ir_blaster             921 non-null    bool
#  7   processor_name             921 non-null    object
#  8   processor_brand            921 non-null    object
#  9   num_cores                  921 non-null    object
#  10  processor_speed            886 non-null    float64
#  11  ram_capacity               921 non-null    int64
#  12  fast_charging_available    921 non-null    int64
# ...

# %%
df1.head()
# Out:
#   brand_name                             model   price  rating  has_5g  \
# 0      apple               Apple iPhone 18 Pro  164900    85.0    True
# 1       vivo  Vivo T4 Pro 5G (8GB RAM + 256GB)   29999    72.0    True
# 2      apple                  Apple iPhone Duo  299900    84.0    True
# 3      apple           Apple iPhone 18 Pro Max  179900    86.0    True
# 4     realme     Realme P1 5G (8GB RAM+ 128GB)   14999    58.0    True
#
#    has_nfc  has_ir_blaster     processor_name processor_brand  num_cores  \
# 0     True           False      Apple A20 Pro          bionic  Hexa Core
# 1    False            True  Snapdragon 7 Gen4      snapdragon  Octa Core
# 2     True           False      Apple A20 Pro          bionic  Hexa Core
# 3     True           False      Apple A20 Pro          bionic  Hexa Core
# 4    False           False     Dimensity 7050       dimensity  Octa Core
#
#    processor_speed  ram_capacity  fast_charging_available  internal_memory  \
# ...

# %%
df1.drop(columns=['processor_name','extended_memory'],inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 921 entries, 0 to 920
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 921 non-null    object
#  1   model                      921 non-null    object
#  2   price                      921 non-null    int64
#  3   rating                     786 non-null    float64
#  4   has_5g                     921 non-null    bool
#  5   has_nfc                    921 non-null    bool
#  6   has_ir_blaster             921 non-null    bool
#  7   processor_brand            921 non-null    object
#  8   num_cores                  921 non-null    object
#  9   processor_speed            886 non-null    float64
#  10  ram_capacity               921 non-null    int64
#  11  fast_charging_available    921 non-null    int64
#  12  internal_memory            921 non-null    int64
# ...

# %%
df1['os'].value_counts()
# Out:
# os
# android    853
# ios         35
# Name: count, dtype: int64

# %%
df1['os'] = df1['os'].replace('Not Specified', np.nan)

# %%
df1['os'].isnull().sum()
# Out:
# np.int64(33)

# %%
df1['rating'].value_counts()
# Out:
# rating
# 66.0    46
# 64.0    41
# 63.0    39
# 55.0    32
# 62.0    32
# 67.0    32
# 57.0    31
# 70.0    30
# 54.0    30
# 75.0    30
# 74.0    29
# 59.0    27
# 58.0    26
# 61.0    26
# 68.0    24
# 53.0    24
# 52.0    23
# 72.0    23
# 71.0    21
# 79.0    19
# 76.0    19
# 84.0    17
# 77.0    17
# 50.0    17
# 85.0    16
# 80.0    15
# 94.0    13
# 81.0    13
# 86.0    12
# 83.0    12
# 88.0    12
# 92.0     6
# 89.0     6
# 98.0     6
# 95.0     6
# 93.0     5
# 90.0     5
# 97.0     4
# Name: count, dtype: int64

# %%
df1['rating'].isnull().sum()
# Out:
# np.int64(135)

# %%
df1['primary_camera_front'].value_counts()
# Out:
# primary_camera_front
# 8.0     191
# 32.0    162
# 16.0    124
# 50.0     99
# 5.0      91
# 12.0     70
# 13.0     65
# 10.0     35
# 20.0     35
# 18.0     19
# 42.0      7
# 10.5      6
# 44.0      1
# 10.8      1
# 7.0       1
# 24.0      1
# 25.0      1
# Name: count, dtype: int64

# %%
df1['primary_camera_front'].isnull().sum()
# Out:
# np.int64(12)

# %%
df1['primary_camera_front'] = df1['primary_camera_front'].replace(0.0, np.nan)

# %%
df1['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core      840
# Hexa Core       39
# Deca Core       19
# Single Core     10
# Dual Core        6
# Quad Core        4
# Nine Core        3
# Name: count, dtype: int64

# %%
df1['num_cores'] = df1['num_cores'].str.replace('Single Core','1')
df1['num_cores'] = df1['num_cores'].str.replace('Dual Core','2')
df1['num_cores'] = df1['num_cores'].str.replace('Quad Core','4')
df1['num_cores'] = df1['num_cores'].str.replace('Hexa Core','6')
df1['num_cores'] = df1['num_cores'].str.replace('Octa Core','8')
df1['num_cores'] = df1['num_cores'].str.replace('Nine Core','9')
df1['num_cores'] = df1['num_cores'].str.replace('Deca Core','10')

# %%
df1['num_cores'] = df1['num_cores'].astype(float)

# %%
df1['num_cores'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       135
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand                0
# num_cores                      0
# processor_speed               35
# ram_capacity                   0
# fast_charging_available        0
# internal_memory                0
# battery_capacity               0
# fast_charging                104
# screen_size                    0
# refresh_rate                   0
# resolution                     0
# primary_camera_front          12
# primary_camera_rear            0
# num_rear_cameras               0
# num_front_cameras              0
# os                            33
# extended_memory_available      0
# extended_upto                587
# dtype: int64

# %%
df1['extended_memory_available'].value_counts()
# Out:
# extended_memory_available
# 0    480
# 1    441
# Name: count, dtype: int64

# %%
df1['fast_charging'] = df1['fast_charging'].replace(0, np.nan)
df1['fast_charging'] = df1['fast_charging'].replace(-1, np.nan)

# %%
df1['num_front_cameras'] = df1['num_front_cameras'].replace(0, np.nan)

# %%
df1['fast_charging'].isnull().sum()
# Out:
# np.int64(104)

# %%
df1.select_dtypes(include=['object'])
# Out:
#     brand_name                                              model  \
# 0        apple                                Apple iPhone 18 Pro
# 1         vivo                   Vivo T4 Pro 5G (8GB RAM + 256GB)
# 2        apple                                   Apple iPhone Duo
# 3        apple                            Apple iPhone 18 Pro Max
# 4       realme                      Realme P1 5G (8GB RAM+ 128GB)
# 5     motorola                            Motorola Edge 70 Fusion
# 6        apple                                    Apple iPhone 17
# 7         vivo                                         Vivo T5 5G
# 8       xiaomi                                 Xiaomi Redmi 17 5G
# 9         poco                                     Poco X7 Pro 5G
# 10     samsung            Samsung Galaxy F16 5G (6GB RAM + 128GB)
# 11        poco                                   Poco X8 Power 5G
# 12     oneplus                                  OnePlus Nord 5 5G
# ...

# %%
df1[df1['os'].isnull()]
# Out:
# Empty DataFrame
# Columns: [brand_name, model, price, rating, has_5g, has_nfc, has_ir_blaster, processor_brand, num_cores, processor_speed, ram_capacity, fast_charging_available, internal_memory, battery_capacity, fast_charging, screen_size, refresh_rate, resolution, primary_camera_front, primary_camera_rear, num_rear_cameras, num_front_cameras, os, extended_memory_available, extended_upto]
# Index: []

# %%
df1[df1['os'].isnull()]['brand_name'].index
# Out:
# Index([], dtype='int64')

# %%
apple_idx = [2, 24, 41, 144]

android_idx = [263, 323, 331, 427, 458, 474, 509, 527, 535, 584,
               608, 648, 653, 666, 684, 695, 697, 723, 724, 732,
               737, 759, 764, 770, 780, 820, 825, 832, 919]

df1.loc[apple_idx, 'os'] = 'ios'
df1.loc[android_idx, 'os'] = 'android'

# %%
df1['brand_name'] = df1['brand_name'].astype('category')

# %%
pd.get_dummies(df1,columns=['brand_name','processor_brand','os'],drop_first=True)
# Out:
#                                                  model   price  rating  \
# 0                                  Apple iPhone 18 Pro  164900    85.0
# 1                     Vivo T4 Pro 5G (8GB RAM + 256GB)   29999    72.0
# 2                                     Apple iPhone Duo  299900    84.0
# 3                              Apple iPhone 18 Pro Max  179900    86.0
# 4                        Realme P1 5G (8GB RAM+ 128GB)   14999    58.0
# 5                              Motorola Edge 70 Fusion   27695    70.0
# 6                                      Apple iPhone 17   82900    76.0
# 7                                           Vivo T5 5G   34999    71.0
# 8                                   Xiaomi Redmi 17 5G   23999    61.0
# 9                                       Poco X7 Pro 5G   23999    70.0
# 10             Samsung Galaxy F16 5G (6GB RAM + 128GB)   13999    55.0
# 11                                    Poco X8 Power 5G   35999    76.0
# ...

# %%
numerical_cols = df1.select_dtypes(include=np.number).columns
x_df = df1[numerical_cols].copy()

# %%
from sklearn.impute import KNNImputer

knn = KNNImputer(n_neighbors=3,weights='distance')

return_array = knn.fit_transform(x_df)

# %%
x = pd.DataFrame(return_array, columns=x_df.columns).corr()['price'].reset_index()

# %%
y = df1.select_dtypes(include=['number']).corr()['price'].reset_index()

# %%
x.merge(y,on='index')
# Out:
#                         index   price_x   price_y
# 0                       price  1.000000  1.000000
# 1                      rating  0.720800  0.694493
# 2                   num_cores -0.078955 -0.078955
# 3             processor_speed  0.794837  0.816550
# 4                ram_capacity  0.624475  0.624475
# 5     fast_charging_available  0.138547  0.138547
# 6             internal_memory  0.793136  0.793136
# 7            battery_capacity -0.129238 -0.129238
# 8               fast_charging  0.218454  0.293087
# 9                 screen_size  0.329174  0.329174
# 10               refresh_rate  0.169072  0.169072
# 11       primary_camera_front  0.169644  0.162338
# 12        primary_camera_rear  0.284108  0.284108
# 13           num_rear_cameras  0.296412  0.296412
# 14          num_front_cameras  0.555326  0.555677
# 15  extended_memory_available -0.472705 -0.472705
# 16              extended_upto  0.057487  0.189607

# %%
df1.to_csv('smartphone_cleaned_v3.csv',index=False)
